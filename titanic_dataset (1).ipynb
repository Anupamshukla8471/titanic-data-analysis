# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_tips = sns.load_dataset("tips")
df_tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df_tips.describe
# Out:
# <bound method NDFrame.describe of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.corr
# correlation define values range between -1 to 1
# 1: Perfect positive correlation.
# 0: No correlation.
#-1: Perfect negative correlation.
# Out:
# <bound method DataFrame.corr of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
sns.heatmap(df_tips.corr(numeric_only="TRUE"))
# df_tips.corr(numeric_only="TRUE")

# Computes the correlation matrix only for numeric columns.
# Out:
# <Axes: >

# %%
sns.heatmap(df_tips.corr(numeric_only='TRUE'),cmap="coolwarm")
# Out:
# <Axes: >

# %%
df_tips["sex"]= df_tips["sex"].map({"Female":1,"Male":0})
df_tips
# Out:
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   1     No   Sun  Dinner     2
# 1         10.34  1.66   0     No   Sun  Dinner     3
# 2         21.01  3.50   0     No   Sun  Dinner     3
# 3         23.68  3.31   0     No   Sun  Dinner     2
# 4         24.59  3.61   1     No   Sun  Dinner     4
# ..          ...   ...  ..    ...   ...     ...   ...
# 239       29.03  5.92   0     No   Sat  Dinner     3
# 240       27.18  2.00   1    Yes   Sat  Dinner     2
# 241       22.67  2.00   0    Yes   Sat  Dinner     2
# 242       17.82  1.75   0     No   Sat  Dinner     2
# 243       18.78  3.00   1     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df_tips["smoker"]=df_tips["smoker"].map({"No":0,"yes":1})
df_tips["day"]=df_tips["day"].map({"Thur":0,"Fri":1,"sat":3,"sun":4})
df_tips.time.map({"Lunch":0,"Dinner":1})
df_tips
# Out:
#      total_bill   tip sex  smoker  day    time  size
# 0         16.99  1.01   1     0.0  NaN  Dinner     2
# 1         10.34  1.66   0     0.0  NaN  Dinner     3
# 2         21.01  3.50   0     0.0  NaN  Dinner     3
# 3         23.68  3.31   0     0.0  NaN  Dinner     2
# 4         24.59  3.61   1     0.0  NaN  Dinner     4
# ..          ...   ...  ..     ...  ...     ...   ...
# 239       29.03  5.92   0     0.0  NaN  Dinner     3
# 240       27.18  2.00   1     NaN  NaN  Dinner     2
# 241       22.67  2.00   0     NaN  NaN  Dinner     2
# 242       17.82  1.75   0     0.0  NaN  Dinner     2
# 243       18.78  3.00   1     0.0  0.0  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.heatmap(df_tips.corr(numeric_only="TRUE"),cmap="coolwarm",annot=True)
# linear regression y=mx+c
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_tips, x="tip", y="sex")
# Out:
# <Axes: xlabel='tip', ylabel='sex'>

# %%
sns.scatterplot(data=df_tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(data=df_tips,x="total_bill",y="tip",hue="smoker",col="sex")

# %%
sns.relplot(data=df_tips,x="total_bill",y="tip",hue="day")

# %%
sns.relplot(data=df_tips,x="total_bill",y="tip",hue="time",col="day")

# %%
sns.relplot(data=df_tips,x="total_bill",y="tip",hue="time",col="day")

# %%
df_titanic = sns.load_dataset("titanic")
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.lineplot(data=df_tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.barplot(data=df_tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(df_tips['total_bill'], df_tips['tip'], color='blue', alpha=0.6)

# %%
# open titanic dataset

# %%
# df column name.drop
